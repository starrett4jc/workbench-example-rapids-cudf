# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# %%
# Step 1: Simulate Vibration Data
# Generate a time array
time = np.linspace(0, 10, 1000)  # Time in seconds

# %%
# Generate normal vibration amplitudes as a sine wave with noise
normal_vibration = np.sin(2 * np.pi * 10 * time) + np.random.normal(0, 0.2, len(time))  # Frequency = 10 Hz

# %%
# Add anomalies (spikes in vibration amplitude)
anomalies = [200, 700]  # Indices of anomalies
vibration_data = normal_vibration.copy()
vibration_data[anomalies] = [3, -3]  # Spikes

# %%
# Plot the vibration data
plt.figure(figsize=(12, 6))
plt.plot(time, vibration_data, label='Vibration Data')
plt.scatter(time[anomalies], vibration_data[anomalies], color='red', label='Injected Anomalies')
plt.title('Simulated Vibration Data with Anomalies')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

# %%
# Step 2: Use K-means Clustering to Detect Outliers
# Prepare the data for K-means clustering
vibration_data_reshaped = vibration_data.reshape(-1, 1)

# %%
# Standardize the data for better clustering performance
scaler = StandardScaler()
vibration_data_scaled = scaler.fit_transform(vibration_data_reshaped)

# %%
# Apply K-means clustering
kmeans = KMeans(n_clusters=2, random_state=42)  # Two clusters: one for normal, one for anomalies
kmeans.fit(vibration_data_scaled)
# Out:
# KMeans(n_clusters=2, random_state=42)

# %%
# Cluster labels
labels = kmeans.labels_  # 0 or 1 based on the cluster assignment

# %%
# Step 3: Identify anomalies
# Assume the smaller cluster represents anomalies
cluster_sizes = np.bincount(labels)
anomaly_cluster = np.argmin(cluster_sizes)  # Cluster with fewer points is likely anomalies
detected_anomalies = np.where(labels == anomaly_cluster)[0]

# %%
# Step 4: Visualize Detected Anomalies
plt.figure(figsize=(12, 6))
plt.plot(time, vibration_data, label='Vibration Data')
plt.scatter(time[detected_anomalies], vibration_data[detected_anomalies], color='orange', label='Detected Anomalies')
plt.scatter(time[anomalies], vibration_data[anomalies], color='red', label='True Anomalies', marker='x', s=100)
plt.title('Vibration Data with Detected Anomalies using K-means')
plt.xlabel('Time (s)')
plt.ylabel('Amplitude')
plt.legend()
plt.show()

# %%
# Step 5: Print Results
print("Detected Anomalies:", detected_anomalies)
# Out:
# Detected Anomalies: [  0   1   2   3   4  10  11  12  13  14  20  21  22  23  24  25  31  32
#   33  34  40  41  42  43  44  45  50  51  52  53  54  60  61  62  63  64
#   65  70  71  72  73  74  81  82  83  84  90  91  92  93  94  95 100 101
#  102 103 104 110 111 112 113 114 120 121 122 123 124 131 132 133 134 141
#  142 143 144 151 152 153 154 160 161 162 163 164 171 172 173 174 181 182
#  183 184 185 190 191 192 193 194 200 201 202 203 204 210 211 212 213 214
#  220 221 222 223 224 230 231 232 233 234 235 241 242 243 244 250 251 252
#  253 254 260 261 262 263 264 265 271 272 273 274 275 280 281 282 283 284
#  290 291 292 293 294 300 301 302 303 304 310 311 312 313 314 315 320 321
#  322 323 324 330 331 332 333 334 340 341 342 343 344 350 351 352 353 354
#  360 361 362 363 364 370 371 372 373 374 380 381 382 383 384 390 391 392
#  393 394 400 401 402 403 404 409 410 411 412 413 414 421 422 423 424 431
#  432 433 434 440 441 442 443 444 445 450 451 452 453 454 460 461 462 463
#  464 470 471 472 473 480 481 482 483 484 490 491 492 493 500 501 502 503
#  504 510 511 512 513 520 521 522 523 524 530 531 532 533 534 540 541 542
#  543 544 550 551 552 553 554 560 561 562 563 564 570 571 572 573 574 580
#  581 582 583 584 590 591 592 593 600 601 602 603 604 609 610 611 612 613
#  614 620 621 622 623 624 630 631 632 633 634 640 641 642 643 644 650 651
#  652 653 654 660 661 662 663 670 671 672 673 674 680 681 682 683 684 690
#  691 692 693 694 701 702 703 710 711 712 713 714 720 721 722 723 724 729
#  730 731 732 733 739 740 741 742 743 744 750 751 752 753 760 761 762 763
#  764 769 770 771 772 773 774 780 781 782 783 784 790 791 792 793 794 800
#  801 802 803 810 811 812 813 814 820 821 822 823 824 830 831 832 833 834
#  840 841 842 843 850 851 852 853 854 859 860 861 862 863 870 871 872 873
#  879 880 881 882 883 890 891 892 893 894 899 900 901 902 903 910 911 912
#  913 919 920 921 922 923 924 930 931 932 933 939 940 941 942 943 950 951
#  952 953 959 960 961 962 963 969 970 971 972 973 974 979 980 981 982 983
#  990 991 992 993 999]
